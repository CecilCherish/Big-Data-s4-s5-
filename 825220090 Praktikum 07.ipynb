# %%
# Cecillia Cherish Mardjuki
# 825220090

# %%
import pandas as pd
import numpy as np
file = "googleplaystore.csv"
df=pd.read_csv(file)
#  membaca data file dan melakukan import library

# %%
print(len(df))
# menampilkan banyak atau lebarnya atau besar data
# Out:
# 10839

# %%
df.head(10)
# menampilkan data 10 teratas
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.iloc[-3:]
# menampilkan 3 baris terakhir
# Out:
#                                                  App             Category  \
# 10836                         Parkinson Exercices FR              MEDICAL
# 10837                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10836     NaN        3                9.5M       1,000+  Free     0
# 10837     4.5      114  Varies with device       1,000+  Free     0
# 10838     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone            Medical  January 20, 2017                   1
# 10837     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10838       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          2.2 and up
# ...

# %%
df.info()
# melihat tiap info dr datasetnya
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10839 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          9365 non-null   float64
#  3   Reviews         10839 non-null  int64
#  4   Size            10839 non-null  object
#  5   Installs        10839 non-null  object
#  6   Type            10838 non-null  object
#  7   Price           10839 non-null  object
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     10837 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.shape
# menampilkan jumlah baris dan kolom dari file csv/data file
# Out:
# (10839, 13)

# %%
df.columns
#  menampilkan kolom yang ada
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.rename(index=str, columns={"Content Rating":"ContentRating",
                              "Last Updated":"LastUpdated", "Current Ver":"CurrentVersion",
                              "Android Ver":"AndroidVersion"}, inplace=True)
# mengganti nama kolom

# %%
df.columns
# mengecek kolom yang telah diperbaharui
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'ContentRating', 'Genres', 'LastUpdated', 'CurrentVersion',
#        'AndroidVersion'],
#       dtype='object')

# %%
duplicatesNum = df.duplicated().sum()
print("There are %d duplicate records"% (duplicatesNum))
#  menampilkan banyaknya data dupilkat
# Out:
# There are 483 duplicate records

# %%
# menggunakan format (tambahan kokonya sama seperti yang diatas)
duplicatesNum = df.duplicated().sum()
print(f"There are {duplicatesNum} duplicate records")
# Out:
# There are 483 duplicate records

# %%
duplicates = df[(df.duplicated())]
duplicatedWithBloodPressure = duplicates[duplicates['App'].str.contains('Blood pressure', case=False)]
# Cara pake shape (ini dan cara dibawah sama aja)
print("%d duplicated records have 'blood pressure' in their name" % (duplicatedWithBloodPressure.shape[0]))
# Cara pake len
print("%d duplicated records have 'blood pressure' in their name" % (len(duplicatedWithBloodPressure)))

# untuk menampilkan data duplicate/double
# Out:
# 9 duplicated records have 'blood pressure' in their name
# 9 duplicated records have 'blood pressure' in their name

# %%
duplicatedWithBloodPressure
# Mencetak baris yang berisi duplikasi blood pressure
# Out:
#                                     App Category  Rating  Reviews  Size  \
# 2502                Free Blood Pressure  MEDICAL     NaN        7  5.7M
# 2512          JH Blood Pressure Monitor  MEDICAL     3.7        9  2.9M
# 6584                 iBP Blood Pressure  MEDICAL     4.4      578  704k
# 6585                     Blood Pressure  MEDICAL     4.2    33033  7.4M
# 6590           Blood Pressure(BP) Diary  MEDICAL     3.7     3596  8.4M
# 6593  BP Journal - Blood Pressure Diary  MEDICAL     5.0        6   26M
# 6594             Blood Pressure Monitor  MEDICAL     4.3       17  6.0M
# 6595           Blood Pressure Companion  MEDICAL     4.2      178  4.8M
# 6598                Free Blood Pressure  MEDICAL     NaN        7  5.7M
#
#         Installs  Type  Price ContentRating   Genres        LastUpdated  \
# 2502      5,000+  Free      0      Everyone  Medical   October 13, 2016
# 2512        500+  Free      0      Everyone  Medical      July 21, 2018
# ...

# %%
duplicatedAppsSum = df.duplicated(subset='App').sum()
print("In fact, there are %d duplicate records"% (duplicatedAppsSum))
# membatasi pengecekan pada kolom nama aplikasi
# Out:
# In fact, there are 1181 duplicate records

# %%
duplicatedApps = df[df.duplicated(subset='App')]
duplicatedAppsSummary =  duplicatedApps['App'].value_counts()
print("The app %s has %d duplicated records" % (duplicatedAppsSummary.index[0], duplicatedAppsSummary[0]))
# menemukan aplikasi yang memiliki jumlah duplikat tertinggi
# Out:
# The app ROBLOX has 8 duplicated records

# %%
duplicatedApps = df[df.duplicated(subset='App')]
dupsPerApp = []
duplicatedAppsNames = duplicatedApps['App'].unique()

for u in duplicatedAppsNames:
  dupsPerApp.append(len(duplicatedApps[duplicatedApps['App']==u]))

dupsPerAppArray = np.array(dupsPerApp)

maxDupRecords = np.max(dupsPerAppArray)
maxDupRecordsApp = duplicatedAppsNames[dupsPerAppArray.argmax()]
print("The app %s has %d duplicated records" % (maxDupRecordsApp, maxDupRecords))
# menemukan aplikasi yang memiliki jumlah duplikat tertinggi
# Out:
# The app ROBLOX has 8 duplicated records

# %%
duplicatedApps[duplicatedApps['App']==maxDupRecordsApp]
# menampilkan semua entri yang terduplikasi untuk aplikasi yang memiliki jumlah duplikat terbanyak
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 1701  ROBLOX     GAME     4.5  4447346  67M  100,000,000+  Free     0
# 1748  ROBLOX     GAME     4.5  4448791  67M  100,000,000+  Free     0
# 1841  ROBLOX     GAME     4.5  4449882  67M  100,000,000+  Free     0
# 1870  ROBLOX     GAME     4.5  4449910  67M  100,000,000+  Free     0
# 2016  ROBLOX   FAMILY     4.5  4449910  67M  100,000,000+  Free     0
# 2088  ROBLOX   FAMILY     4.5  4450855  67M  100,000,000+  Free     0
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
# 4527  ROBLOX   FAMILY     4.5  4443407  67M  100,000,000+  Free     0
#
#      ContentRating                        Genres    LastUpdated  \
# 1701  Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1748  Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1841  Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# 1870  Everyone 10+  Adventure;Action & Adventure  July 31, 2018
# ...

# %%
d1 = pd.concat([df[2976:2977], df[3007:3008]])
d2 = pd.concat([df[3015:3016], df[3020:3021]])
d1
# menggabungkan dua potongan data dari DataFrame df untuk membentuk dua DataFrame baru, d1 dan d2
# Out:
#                                                     App Category  Rating  \
# 2976  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
# 3007  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
#
#       Reviews                Size    Installs  Type Price ContentRating  \
# 2976    91031  Varies with device  5,000,000+  Free     0      Everyone
# 3007    91031  Varies with device  5,000,000+  Free     0      Everyone
#
#       Genres     LastUpdated      CurrentVersion AndroidVersion
# 2976  Sports  August 4, 2018  Varies with device     5.0 and up
# 3007  Sports  August 4, 2018  Varies with device     5.0 and up

# %%
d3=pd.concat([df[3020:3021], df[3056:3057]])
d3
# menggabungkan dua potongan data dari DataFrame df untuk membentuk DataFrame baru d3
# Out:
#                                                     App Category  Rating  \
# 3020  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
# 3056  CBS Sports App - Scores, News, Stats & Watch Live   SPORTS     4.3
#
#       Reviews                Size    Installs  Type Price ContentRating  \
# 3020    91031  Varies with device  5,000,000+  Free     0      Everyone
# 3056    91033  Varies with device  5,000,000+  Free     0      Everyone
#
#       Genres     LastUpdated      CurrentVersion AndroidVersion
# 3020  Sports  August 4, 2018  Varies with device     5.0 and up
# 3056  Sports  August 4, 2018  Varies with device     5.0 and up

# %%
dfClean = df.drop_duplicates(subset='App', keep='last')
dfClean.shape
# menghapus baris yang duplikat berdasarkan kolom 'App' dari DataFrame df dan menyimpan baris terakhir dari setiap kelompok duplikat
# lalu mengecek dengan manempilkan jumlah kolom dan baris
# Out:
# (9658, 13)

# %%
dfClean.loc[:, 'LastUpdated'] = pd.to_datetime(dfClean['LastUpdated'], format='%B %d, %Y')
# membuat variable dari awal smpe last update dan formatnya

# %%
print(dfClean['LastUpdated'])
# menampilkan tanggal waktu last update
# Out:
# 0        2018-01-07 00:00:00
# 2        2018-08-01 00:00:00
# 3        2018-06-08 00:00:00
# 4        2018-06-20 00:00:00
# 5        2017-03-26 00:00:00
#                 ...
# 10834    2017-07-25 00:00:00
# 10835    2018-07-06 00:00:00
# 10836    2017-01-20 00:00:00
# 10837    2015-01-19 00:00:00
# 10838    2018-07-25 00:00:00
# Name: LastUpdated, Length: 9658, dtype: object

# %%
# sama seperti yg diatas hanya beda ini menggunakan loc
dfClean.loc[:, 'LastUpdated']
# Out:
# 0        2018-01-07 00:00:00
# 2        2018-08-01 00:00:00
# 3        2018-06-08 00:00:00
# 4        2018-06-20 00:00:00
# 5        2017-03-26 00:00:00
#                 ...
# 10834    2017-07-25 00:00:00
# 10835    2018-07-06 00:00:00
# 10836    2017-01-20 00:00:00
# 10837    2015-01-19 00:00:00
# 10838    2018-07-25 00:00:00
# Name: LastUpdated, Length: 9658, dtype: object

# %%
sortedLastUpdated = dfClean['LastUpdated'].sort_values()
print("%s is the least recently updated application and was updated on %s"% (dfClean.loc[sortedLastUpdated.index[0]]['App'],
                                                                             str(sortedLastUpdated[0])))
# untuk mengetahui aplikasi apa yang terkhir diupdate beserta tanggalnya
# Out:
# CJ Poker Odds Calculator is the least recently updated application and was updated on 2011-01-30 00:00:00

# %%
uniquePricesNum = dfClean['Price'].nunique()
uniquePrices = dfClean['Price'].unique()
# print("There are %d unique price values. The first five are %s" % (uniquePricesNum, uniquePrices[:5]))
# print("There are %d unique price values. The first five are %s" % (len(uniquePrices), uniquePrices[:5]))

# versi lain tp sama aja
print(f"There are {uniquePricesNum} unique price values. The first five are")
print("There are {} unique price values. The first five are".format(len(uniquePrices)))

# mencetak data harga unik lima pertama
# Out:
# There are 92 unique price values. The first five are
# There are 92 unique price values. The first five are

# %%
def moneyWithoutCurrencySymbol(v):
  if type(v) is not float:
    return float(v.replace("$", ""))
  else:
    return v
# menulis simbol mata uang tanpa simbol mata uang

# %%
dfClean[dfClean['App']=="Moco+ - Chat, Meet People"]
# mengubah variable price menjadi float
# Out:
#                            App Category  Rating  Reviews                Size  \
# 571  Moco+ - Chat, Meet People   DATING     4.2     1546  Varies with device
#
#     Installs  Type  Price ContentRating  Genres          LastUpdated  \
# 571  10,000+  Paid   3.99    Mature 17+  Dating  2018-06-19 00:00:00
#
#     CurrentVersion AndroidVersion
# 571        2.6.139     4.1 and up

# %%
# solution 1
dfClean.loc[:, 'Price'] = dfClean['Price'].apply(moneyWithoutCurrencySymbol)
# menghapus simbol mata uang dari nilai yang disimpan dalam kolom 'Price'

# %%
# solution 2 slide26
dfClean["Price"] = dfClean["Price"].astype(str)

# mengubah tanda dolar ke numerik
dfClean['Price'] = pd.to_numeric(dfClean['Price'].str.strip('$'))
# Out:
# <ipython-input-53-5b742cde73e9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean["Price"] = dfClean["Price"].astype(str)
# <ipython-input-53-5b742cde73e9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['Price'] = pd.to_numeric(dfClean['Price'].str.strip('$'))

# %%
dfClean.isna().sum()
dfClean.isnull().sum()
# menghitung jumlah nilai yang hilang (NaN)
# Out:
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# ContentRating        0
# Genres               0
# LastUpdated          0
# CurrentVersion       8
# AndroidVersion       2
# dtype: int64

# %%
# versi lain dari yang atas
dfClean.isna().sum()/len(dfClean) * 100
# menghitung jumlah nilai yang hilang (NaN)
# Out:
# App                0.000000
# Category           0.000000
# Rating            15.148064
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.010354
# Price              0.000000
# ContentRating      0.000000
# Genres             0.000000
# LastUpdated        0.000000
# CurrentVersion     0.082833
# AndroidVersion     0.020708
# dtype: float64

# %%
dfClean['Type'] = dfClean['Type'].fillna(dfClean['Type'].mode()[0])
# mengisi nilai yang hilang dalam kolom 'Type' dari DataFrame dfClean dengan nilai modus
# Out:
# <ipython-input-57-2b34a1613ff8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['Type'] = dfClean['Type'].fillna(dfClean['Type'].mode()[0])

# %%
dfClean[dfClean['App'] == 'Command & Conquer: Rivals']
# mencari baris dari dataframe yang app bernama Command & Conquer: Rivals
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9147  Command & Conquer: Rivals   FAMILY     NaN        0  Varies with device
#
#      Installs  Type  Price ContentRating    Genres          LastUpdated  \
# 9147        0  Free    0.0  Everyone 10+  Strategy  2018-06-28 00:00:00
#
#           CurrentVersion      AndroidVersion
# 9147  Varies with device  Varies with device

# %%
dfClean['AndroidVersion'] = dfClean['AndroidVersion'].fillna(dfClean['AndroidVersion'].mode()[0])
dfClean['CurrentVersion'] = dfClean['CurrentVersion'].fillna(dfClean['CurrentVersion'].mode()[0])
# mengisi nilai-nilai yang hilang (NaN) dalam kolom 'AndroidVersion' dan 'CurrentVersion' dengan mode (nilai yang paling sering muncul) dari masing-masing kolom
# Out:
# <ipython-input-59-219154acaf90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['AndroidVersion'] = dfClean['AndroidVersion'].fillna(dfClean['AndroidVersion'].mode()[0])
# <ipython-input-59-219154acaf90>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['CurrentVersion'] = dfClean['CurrentVersion'].fillna(dfClean['CurrentVersion'].mode()[0])

# %%
# solution 2
dfClean[dfClean['AndroidVersion'].isna()]
dfClean['AndroidVersion'].mode()
dfClean.loc[dfClean['AndroidVersion'].isna(), 'AndroidVersion'] = dfClean['AndroidVersion'].mode()[0]
# mengisi nilai yang hilang dalam kolom 'AndroidVersion' dengan mode

# %%
dfClean[dfClean['App'] == '[substratum] Vacuum: P']
# mencari nama app sesuai yang diminta yaitu [substratum] Vacuum: P
# Out:
#                          App         Category  Rating  Reviews Size Installs  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4      230  11M   1,000+
#
#       Type  Price ContentRating           Genres          LastUpdated  \
# 4453  Paid   1.49      Everyone  Personalization  2018-07-20 00:00:00
#
#      CurrentVersion AndroidVersion
# 4453            4.4     4.1 and up

# %%
dfClean[dfClean['App'] == 'Pi Dark [substratum]']
# mencari nama app sesuai yang diminta yaitu Pi Dark [substratum]
# Out:
#                        App         Category  Rating  Reviews  Size Installs  \
# 4490  Pi Dark [substratum]  PERSONALIZATION     4.5      189  2.1M  10,000+
#
#       Type  Price ContentRating           Genres          LastUpdated  \
# 4490  Free    0.0      Everyone  Personalization  2018-03-27 00:00:00
#
#      CurrentVersion AndroidVersion
# 4490            1.1     4.1 and up

# %%
#Solution2
dfClean.loc[dfClean['Type'].isna(), 'Type'] = dfClean['Type'].mode()[0]
dfClean.loc[dfClean['AndroidVersion'].isna(), 'AndroidVersion'] = dfClean['AndroidVersion'].mode()[0]
dfClean.loc[dfClean['CurrentVersion'].isna(), 'CurrentVersion'] = dfClean['CurrentVersion'].mode()[0]
# mengisi nilai yang hilang dalam kolom-kolom tersebut dengan mode masing-masing

# %%
#Solution1
dfClean['Rating'] = dfClean['Rating'].fillna(0)
dfClean[dfClean['Rating']==0]
# memperhitungkan record Rating NaN tersebut dengan nilai minimum 0
# Out:
# <ipython-input-68-0009c8675f58>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['Rating'] = dfClean['Rating'].fillna(0)
#                                        App             Category  Rating  \
# 113              Wrinkles and rejuvenation               BEAUTY     0.0
# 123                 Manicure - nail design               BEAUTY     0.0
# 126           Skin Care and Natural Beauty               BEAUTY     0.0
# 129    Secrets of beauty, youth and health               BEAUTY     0.0
# 130     Recipes and tips for losing weight               BEAUTY     0.0
# ...                                    ...                  ...     ...
# 10822                            Cardio-FR              MEDICAL     0.0
# ...

# %%
#Solution2
dfClean.loc[dfClean['Rating'].isna(), 'Rating'] = 0
# memperhitungkan record Rating NaN tersebut dengan nilai minimum 0

# %%
dfClean['Installs'].unique()
# Memeriksa nilai unik dari Installs
# Out:
# array(['10,000+', '5,000,000+', '50,000,000+', '100,000+', '50,000+',
#        '1,000,000+', '10,000,000+', '5,000+', '500,000+',
#        '1,000,000,000+', '100,000,000+', '1,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '500,000,000+', '0+', '0'], dtype=object)

# %%
dfClean.loc[dfClean["Installs"]=="0","Installs"] = "0+"
# diubah menjadikan homogen dan mengubah 0 menjadi 0+

# %%
dfClean[(dfClean['Installs']=="0")]
# memeriksa pembersihan jika dilakukan
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, LastUpdated, CurrentVersion, AndroidVersion]
# Index: []

# %%
def sizeToFloat (v):
  if "M" in v:
    return float(v.strip("M"))

  elif v[-1]=="k":
    return float(v.strip("k"))/1024
  else:
    return 1.0

dfClean['Size'] = dfClean['Size'].apply(sizeToFloat)
# mengubah size menjadi float, dan mengubahnya menjadi megabyte
# Out:
# <ipython-input-73-3615c517273a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean['Size'] = dfClean['Size'].apply(sizeToFloat)

# %%
sortedSize = dfClean['Size'].sort_values()
print("%s is the smallest application and its size is %.4fM" % (dfClean.loc[sortedSize.index[0]]['App'], sortedSize[0]))
# mecari aplikasi terkecil dan berapa ukurannya
# Out:
# Essential Resources is the smallest application and its size is 0.0083M

# %%
# mencari aplikasi terbesar
largestApps = dfClean.loc[sortedSize[sortedSize==sortedSize[-1]].index]
largestAppsCategory = largestApps['Category'].mode()[0]
largestAppsCategoryNames = largestApps[largestApps['Category']==largestAppsCategory]['App']
print("The most common category of the largest applications is  ",
      largestAppsCategory)
print("The applications that belong to this category are\n",
      largestAppsCategoryNames.values)
# mencari aplikasi terbesar manakah yang paling umum
# Out:
# The most common category of the largest applications is   GAME
# The applications that belong to this category are
#  ['Car Crash III Beam DH Real Damage Simulator 2018'
#  'Mini Golf King - Multiplayer Game' 'The Walking Dead: Our World'
#  'Miami crime simulator' 'Stickman Legends: Shadow Wars'
#  'Hungry Shark Evolution']

# %%
free = dfClean[(dfClean['Price']>0) & (dfClean['Type']=="Free") ]
paid = dfClean[(dfClean['Price']<=0) & (dfClean['Type']=="Paid") ]
print ("The are %d Free applications for which you have to pay" % (len(free)))
print ("The are %d Paid applications which are given for free" % (len(paid)))
# untuk mengecek apakah free price 0 dan paid price diatas 0
# Out:
# The are 0 Free applications for which you have to pay
# The are 0 Paid applications which are given for free

# %%
dfClean[(dfClean['Reviews']==0) & (dfClean['Rating']>0)]
# memeriksa aplikasi tanpa ulasan apapun yang memiliki peringkat di atas 0
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, ContentRating, Genres, LastUpdated, CurrentVersion, AndroidVersion]
# Index: []

# %%
dfClean.describe()
# menampilkan deskripsi statistik
# Out:
#             Rating       Reviews         Size        Price
# count  9658.000000  9.658000e+03  9658.000000  9658.000000
# mean      3.541054  2.166735e+05    17.935304     1.097344
# std       1.575689  1.830831e+06    21.393800    16.852487
# min       0.000000  0.000000e+00     0.008301     0.000000
# 25%       3.600000  2.500000e+01     2.900000     0.000000
# 50%       4.200000  9.680000e+02     9.100000     0.000000
# 75%       4.500000  2.940800e+04    25.000000     0.000000
# max       5.000000  7.812821e+07   100.000000   400.000000

# %%
from datetime import datetime,date

dfClean["NotUpdatedFor"]  = pd.to_datetime(datetime.today().strftime("%m-%d-%Y"))
dfClean["LastUpdated"]

dfClean.head()
# menampilkan 5 terdepan/atas

# membuat kolom baru yang memiliki kolom variabel Last Updated dan tanggal sekarang untuk mengetahui perbedaan
# Out:
# <ipython-input-80-cc541f218732>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClean["NotUpdatedFor"]  = pd.to_datetime(datetime.today().strftime("%m-%d-%Y"))
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
#
#    Reviews  Size     Installs  Type  Price ContentRating  \
# ...
